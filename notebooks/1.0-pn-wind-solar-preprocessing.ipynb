# %%
import pandas as pd
import numpy as np

# %%
import sys
print(sys.executable)
# Out:
# /home/pawel/day-ahead/env/bin/python

# %% [markdown]
# Wczytywanie danych

# %%
df = pd.read_csv("../data/processed/pl_gen_wiatr.csv", index_col='date', parse_dates=True)

# %%
df.head()
# Out:
#                          wind  solar
# date
# 2020-01-01 00:00:00  2696.909    0.0
# 2020-01-01 01:00:00  2503.293    0.0
# 2020-01-01 02:00:00  2500.017    0.0
# 2020-01-01 03:00:00  2395.943    0.0
# 2020-01-01 04:00:00  2305.066    0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 34289 entries, 2020-01-01 00:00:00 to 2023-11-30 07:00:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   wind    34289 non-null  float64
#  1   solar   34289 non-null  float64
# dtypes: float64(2)
# memory usage: 803.6 KB

# %%
df.describe()
# Out:
#                wind         solar
# count  34289.000000  34289.000000
# mean    1988.807038    836.351106
# std     1617.462101   1555.115686
# min       14.738000     -0.013000
# 25%      727.025000      0.000000
# 50%     1513.038000     14.975000
# 75%     2866.148000    938.238000
# max     8205.950000   9274.863000

# %%
df.isnull().sum()
# Out:
# wind     0
# solar    0
# dtype: int64

# %%
filtered_df = df[df.index >= '2020-04-20']

# %%
print(filtered_df.head())
# Out:
#                          wind  solar
# date
# 2020-04-20 00:00:00  1470.081   0.00
# 2020-04-20 01:00:00  1273.581   0.00
# 2020-04-20 02:00:00  1081.042   0.00
# 2020-04-20 03:00:00  1043.218   0.00
# 2020-04-20 04:00:00   955.528   1.99

# %% [markdown]
# Eksploracja danych

# %%
filtered_df.hist()
# Out:
# array([[<Axes: title={'center': 'wind'}>,
#         <Axes: title={'center': 'solar'}>]], dtype=object)

# %%
filtered_df['wind'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
filtered_df['solar'].plot()
# Out:
# <Axes: xlabel='date'>
